# %%
import pandas as pd

# %%
df=pd.read_csv("cricinfo.csv")

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    PHKD Mendis (SL)  2022-2025   12    21   2  1184  182*  62.31   1839
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 57   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 58  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 59  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 60    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 61   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0    58.6   29  13   7   626   6
# ...

# %%
df['country']=df['Player'].str.split(pat='(').str[1]
df['country']=df['country'].str.split(pat=')').str[0]
df['Player']=df['Player'].str.split(pat='(').str[0]
df['start_year']=df['Span'].str.split(pat='-').str[0].astype(int)
df['end_year']=df['Span'].str.split(pat='-').str[1].astype(int)
df.rename(columns={'Span':'Duration','Mat':'Matches','BF':'Balls_face','HS':'High_score','SR':'Strike_rate'},inplace=True)
df['Duration']=df['end_year']-df['start_year']
df['High_score']=df['High_score'].str.split(pat='*').str[0].astype(int)
df['Balls_face']=df['Balls_face'].str.split(pat='+').str[0]
df['Balls_face']=df['Balls_face'].replace('-',0)
df['Balls_face']=df['Balls_face'].astype(int)
df['Strike_rate']=df['Strike_rate'].replace('-',0)
df['Strike_rate']=df['Strike_rate'].astype(float)
df['0']=df['0'].replace('-',0)
df['0']=df['0'].astype(int)

# %%
df.head()
# Out:
#          Player  Duration  Matches  Inns  NO  Runs  High_score    Ave  \
# 0   DG Bradman         20       52    80  10  6996         334  99.94
# 1  PHKD Mendis          3       12    21   2  1184         182  62.31
# 2     AC Voges          1       20    31   7  1485         269  61.87
# 3   RG Pollock          7       23    41   4  2256         274  60.97
# 4   GA Headley         24       22    40   4  2190         270  60.83
#
#    Balls_face  Strike_rate  100  50  0   4s  6s country  start_year  end_year
# 0        9800        58.60   29  13  7  626   6     AUS        1928      1948
# 1        1839        64.38    5   4  0  123  23      SL        2022      2025
# 2        2667        55.68    5   4  2  186   5     AUS        2015      2016
# 3        1707        54.48    7  11  1  246  11      SA        1963      1970
# 4         416        56.00   10   5  2  104   1      WI        1930      1954

# %%
df.rename(columns={'Ave':'Average'},inplace=True)

# %%
df.to_csv('newcricinfo.csv',index=False)
